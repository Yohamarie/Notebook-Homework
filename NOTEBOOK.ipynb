# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Yohanna Rodrìguez**
#
# I am a teacher

# %% [markdown]
# *I am interested in Data science because I believe that it's going to help to develop new technologies*
#
# *I want to learn Data Science becuase I think that it is very interesting*

# %% [markdown]
# ### In this cell I will explain what I am going to do in the next cell: My code must be executed and must display an output.

# %%
2 - 1
# Out:
# 1

# %% [markdown]
# ### Link
#
# <a href="https://www.google.com"> Link to Google.com</a>
#
# ### Image
#
# <img src="https://lh3.googleusercontent.com/IALGyI3i7Qb9uWcDuwRadPgPJIYWSlDBsHBjbjxoj4KFbUahMiL2oU9JkQ3DYJGxYhQiy3zPhwoMKPLiPtECygIJltA07tvEvUAgftyQq7z421_0XA=w1200" width ="450" height=350>
#
# ### List
#
# <ul> Colors List
# <li>Red</li>
# <li>Blue</li>
# <li>Black</li>
# </ul>
